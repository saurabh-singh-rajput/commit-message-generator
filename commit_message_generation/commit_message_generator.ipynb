# %% [markdown]
# ## Automated commit message generation

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==1.4.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: aiohttp==3.8.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (3.8.4)
# Requirement already satisfied: aiosignal==1.3.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: anyio==3.6.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (3.6.2)
# Requirement already satisfied: appnope==0.1.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.1.3)
# Requirement already satisfied: argon2-cffi==21.3.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (21.2.0)
# Requirement already satisfied: arrow==1.2.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.2.3)
# Requirement already satisfied: asttokens==2.2.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (2.2.1)
# Requirement already satisfied: async-timeout==4.0.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (4.0.2)
# Requirement already satisfied: attrs==22.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (22.2.0)
# Requirement already satisfied: backcall==0.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.11.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (4.11.2)
# Requirement already satisfied: bleach==6.0.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (6.0.0)
# Requirement already satisfied: certifi==2022.12.7 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (2022.12.7)
# Requirement already satisfied: cffi==1.15.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (1.15.1)
# Requirement already satisfied: charset-normalizer==3.1.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (3.1.0)
# Requirement already satisfied: click==8.1.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.1.3)
# Requirement already satisfied: comm==0.1.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (0.1.2)
# Requirement already satisfied: datasets==2.10.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (2.10.1)
# Requirement already satisfied: debugpy==1.6.6 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (1.6.6)
# Requirement already satisfied: decorator==5.1.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.7.1)
# Requirement already satisfied: dill==0.3.6 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (0.3.6)
# Requirement already satisfied: evaluate==0.4.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.4.0)
# Requirement already satisfied: executing==1.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.16.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (2.16.3)
# Requirement already satisfied: filelock==3.10.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (3.10.0)
# Requirement already satisfied: fqdn==1.5.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (1.5.1)
# Requirement already satisfied: frozenlist==1.3.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (1.3.3)
# Requirement already satisfied: fsspec==2023.3.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (2023.3.0)
# Requirement already satisfied: huggingface-hub==0.13.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.13.2)
# Requirement already satisfied: idna==3.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (3.4)
# Requirement already satisfied: importlib-metadata==6.0.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (6.0.0)
# Requirement already satisfied: ipykernel==6.21.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (6.21.3)
# Requirement already satisfied: ipython==8.11.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (8.11.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.0.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (8.0.4)
# Requirement already satisfied: isoduration==20.11.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (20.11.0)
# Requirement already satisfied: jedi==0.18.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (3.1.2)
# Requirement already satisfied: joblib==1.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (1.2.0)
# Requirement already satisfied: jsonpointer==2.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (2.3)
# Requirement already satisfied: jsonschema==4.17.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (4.17.3)
# Requirement already satisfied: jupyter==1.0.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (1.0.0)
# Requirement already satisfied: jupyter-console==6.6.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 46)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.6.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 47)) (0.6.3)
# Requirement already satisfied: jupyter_client==8.0.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 48)) (8.0.3)
# Requirement already satisfied: jupyter_core==5.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 49)) (5.2.0)
# Requirement already satisfied: jupyter_server==2.4.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 50)) (2.4.0)
# Requirement already satisfied: jupyter_server_terminals==0.4.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 51)) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 52)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==3.0.5 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 53)) (3.0.5)
# Requirement already satisfied: MarkupSafe==2.1.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 54)) (2.1.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 55)) (0.1.6)
# Requirement already satisfied: mistune==2.0.5 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 56)) (2.0.5)
# Requirement already satisfied: mpmath==1.3.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 57)) (1.3.0)
# Requirement already satisfied: multidict==6.0.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 58)) (6.0.4)
# Requirement already satisfied: multiprocess==0.70.14 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 59)) (0.70.14)
# Requirement already satisfied: nbclassic==0.5.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 60)) (0.5.3)
# Requirement already satisfied: nbclient==0.7.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 61)) (0.7.2)
# Requirement already satisfied: nbconvert==7.2.10 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 62)) (7.2.10)
# Requirement already satisfied: nbformat==5.7.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 63)) (5.7.3)
# Requirement already satisfied: nest-asyncio==1.5.6 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 64)) (1.5.6)
# Requirement already satisfied: networkx==3.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 65)) (3.0)
# Requirement already satisfied: nltk==3.8.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 66)) (3.8.1)
# Requirement already satisfied: notebook==6.5.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 67)) (6.5.3)
# Requirement already satisfied: notebook_shim==0.2.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 68)) (0.2.2)
# Requirement already satisfied: numpy==1.24.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 69)) (1.24.2)
# Requirement already satisfied: packaging==23.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 70)) (23.0)
# Requirement already satisfied: pandas==1.5.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 71)) (1.5.3)
# Requirement already satisfied: pandocfilters==1.5.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 72)) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 73)) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 74)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 75)) (0.7.5)
# Requirement already satisfied: platformdirs==3.1.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 76)) (3.1.1)
# Requirement already satisfied: prometheus-client==0.16.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 77)) (0.16.0)
# Requirement already satisfied: prompt-toolkit==3.0.38 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 78)) (3.0.38)
# Requirement already satisfied: psutil==5.9.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 79)) (5.9.4)
# Requirement already satisfied: ptyprocess==0.7.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 80)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 81)) (0.2.2)
# Requirement already satisfied: pyarrow==11.0.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 82)) (11.0.0)
# Requirement already satisfied: pycparser==2.21 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 83)) (2.21)
# Requirement already satisfied: Pygments==2.14.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 84)) (2.14.0)
# Requirement already satisfied: pyrsistent==0.19.3 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 85)) (0.19.3)
# Requirement already satisfied: python-dateutil==2.8.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 86)) (2.8.2)
# Requirement already satisfied: python-json-logger==2.0.7 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 87)) (2.0.7)
# Requirement already satisfied: pytz==2022.7.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 88)) (2022.7.1)
# Requirement already satisfied: PyYAML==6.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 89)) (6.0)
# Requirement already satisfied: pyzmq==25.0.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 90)) (25.0.1)
# Requirement already satisfied: qtconsole==5.4.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 91)) (5.4.1)
# Requirement already satisfied: QtPy==2.3.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 92)) (2.3.0)
# Requirement already satisfied: regex==2022.10.31 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 93)) (2022.10.31)
# Requirement already satisfied: requests==2.28.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 94)) (2.28.2)
# Requirement already satisfied: responses==0.18.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 95)) (0.18.0)
# Requirement already satisfied: rfc3339-validator==0.1.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 96)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 97)) (0.1.1)
# Requirement already satisfied: rouge-score==0.1.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 98)) (0.1.2)
# Requirement already satisfied: Send2Trash==1.8.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 99)) (1.8.0)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 100)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 101)) (1.3.0)
# Requirement already satisfied: soupsieve==2.4 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 102)) (2.4)
# Requirement already satisfied: stack-data==0.6.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 103)) (0.6.2)
# Requirement already satisfied: sympy==1.11.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 104)) (1.11.1)
# Requirement already satisfied: terminado==0.17.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 105)) (0.17.1)
# Requirement already satisfied: tinycss2==1.2.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 106)) (1.2.1)
# Requirement already satisfied: tokenizers==0.13.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 107)) (0.13.2)
# Requirement already satisfied: torch==2.0.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 108)) (2.0.0)
# Requirement already satisfied: tornado==6.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 109)) (6.2)
# Requirement already satisfied: tqdm==4.65.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 110)) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 111)) (5.9.0)
# Requirement already satisfied: transformers==4.27.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 112)) (4.27.1)
# Requirement already satisfied: typing_extensions==4.5.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 113)) (4.5.0)
# Requirement already satisfied: uri-template==1.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 114)) (1.2.0)
# Requirement already satisfied: urllib3==1.26.15 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 115)) (1.26.15)
# Requirement already satisfied: wcwidth==0.2.6 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 116)) (0.2.6)
# Requirement already satisfied: webcolors==1.12 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 117)) (1.12)
# Requirement already satisfied: webencodings==0.5.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 118)) (0.5.1)
# Requirement already satisfied: websocket-client==1.5.1 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 119)) (1.5.1)
# Requirement already satisfied: widgetsnbextension==4.0.5 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 120)) (4.0.5)
# Requirement already satisfied: xxhash==3.2.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 121)) (3.2.0)
# Requirement already satisfied: yarl==1.8.2 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 122)) (1.8.2)
# Requirement already satisfied: zipp==3.15.0 in ./venv/lib/python3.9/site-packages (from -r requirements.txt (line 123)) (3.15.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Read filtered data
#
# This **filtered_data.csv** is the result of passing around ~63000 data points through the filter proposed in this [paper](https://arxiv.org/pdf/2202.02974.pdf). The filter retains the messages that contain the aspect of both *why* and *what* in the message.

# %%
import pandas as pd
data = pd.read_csv("data/filtered_data.csv")

# %% [markdown]
# ### Preprocess data
#
# We read the diff and messages tables seperately and then combine them into one dataframe : "data"

# %%
data.head()
# Out:
#    Unnamed: 0                                               diff  \
# 0           0  mmm a / README . md <nl> ppp b / README . md <...
# 1           1  Binary files a / bigbluebutton - client / bran...
# 2           2  mmm a / util - taglib / src / com / liferay / ...
# 3           3  mmm a / bindings / cpp / configure . ac <nl> p...
# 4           4  mmm a / owncloud - android - library <nl> ppp ...
#
#                                              message
# 0      updated read me more documentation to come !
# 1                    Updated fit - to - screen icon
# 2                   LPS - 64187 update package info
# 3                 Remove unneeded check for cppunit
# 4  Updated library to fix bug in SAML authenticat...

# %%
# Dropping the unnecessary index column: "Unnamed: 0"

data.drop(data.columns[0], inplace=True, axis=1)

# %%
data.head()
# Out:
#                                                 diff  \
# 0  mmm a / README . md <nl> ppp b / README . md <...
# 1  Binary files a / bigbluebutton - client / bran...
# 2  mmm a / util - taglib / src / com / liferay / ...
# 3  mmm a / bindings / cpp / configure . ac <nl> p...
# 4  mmm a / owncloud - android - library <nl> ppp ...
#
#                                              message
# 0      updated read me more documentation to come !
# 1                    Updated fit - to - screen icon
# 2                   LPS - 64187 update package info
# 3                 Remove unneeded check for cppunit
# 4  Updated library to fix bug in SAML authenticat...

# %%
# Renaming the column

data.rename(columns = {'diff':'commits'}, inplace=True)

# %%
# Checking for any missing values

data.isna().any()
# Out:
# commits    False
# message    False
# dtype: bool

# %% [markdown]
# ### Train and test splits
#
# 85% of the data is for training
#
# 15% of the data is for validation
#
# We have a seperate set for testing the data

# %%
val_data = data.iloc[:int(len(data)*0.085),:]
train_data = data.iloc[int(len(data)*0.085):,:]

# %% [markdown]
# Resetting indexes after the split

# %%
val_data.reset_index(drop=True, inplace=True)
train_data.reset_index(drop=True, inplace=True)

# %%
print("Train and validation data length",len(train_data)," ",len(val_data))
# Out:
# Train and test length 27707   2573

# %% [markdown]
# Now, we have train and test dataset: each dataset consists of code-diff data and commit messages.

# %% [markdown]
# ### Model
#
# Encoder-Decoder Model from Hugginface. The inspiration for this comes from this [paper](https://arxiv.org/abs/1907.12461)
#
# We will be using CodebERT as an Encoder and GPT-2 as Decoder. We then fine-this on our dataset of commits and corresponding messages.

# %% [markdown]
# Importing libraries : AutoTokenizer for tokenizing the input according to codebert input format and EncoderDecoder model to construct the entire model

# %%
from transformers import AutoTokenizer
from transformers import EncoderDecoderModel

# %% [markdown]
# ### Initialize the model with encoder and decoder

# %%
model = EncoderDecoderModel.from_encoder_decoder_pretrained("microsoft/graphcodebert-base", "gpt2")
# Out:
# Some weights of the model checkpoint at microsoft/graphcodebert-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at microsoft/graphcodebert-base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.crossattention.c_attn.weight', 'h.7.ln_cross_attn.weight', 'h.0.crossattention.masked_bias', 'h.8.crossattention.q_attn.weight', 'h.9.crossattention.q_attn.weight', 'h.5.ln_cross_attn.weight', 'h.8.crossattention.c_attn.weight', 'h.4.ln_cross_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.7.crossattention.bias', 'h.6.crossattention.masked_bias', 'h.11.crossattention.masked_bias', 'h.10.crossattention.masked_bias', 'h.10.ln_cross_attn.weight', 'h.10.crossattention.c_proj.weight', 'h.11.crossattention.c_proj.bias', 'h.3.crossattention.masked_bias', 'h.1.crossattention.c_attn.weight', 'h.1.crossattention.q_attn.weight', 'h.1.crossattention.masked_bias', 'h.5.crossattention.masked_bias', 'h.8.crossattention.masked_bias', 'h.4.crossattention.c_proj.weight', 'h.4.crossattention.masked_bias', 'h.1.crossattention.c_proj.bias', 'h.3.crossattention.c_proj.weight', 'h.1.crossattention.bias', 'h.1.crossattention.c_proj.weight', 'h.0.crossattention.c_proj.bias', 'h.0.ln_cross_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.2.crossattention.q_attn.weight', 'h.11.crossattention.q_attn.weight', 'h.8.crossattention.c_proj.bias', 'h.5.crossattention.c_attn.weight', 'h.3.crossattention.c_attn.weight', 'h.10.crossattention.c_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.4.crossattention.bias', 'h.11.crossattention.c_proj.weight', 'h.9.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.bias', 'h.10.crossattention.q_attn.weight', 'h.7.crossattention.c_attn.weight', 'h.8.crossattention.bias', 'h.9.crossattention.c_attn.weight', 'h.9.crossattention.c_proj.weight', 'h.6.ln_cross_attn.weight', 'h.2.crossattention.c_proj.weight', 'h.7.crossattention.q_attn.weight', 'h.4.crossattention.c_attn.weight', 'h.3.crossattention.bias', 'h.5.crossattention.bias', 'h.0.crossattention.q_attn.weight', 'h.0.crossattention.c_proj.weight', 'h.4.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.weight', 'h.7.crossattention.c_proj.weight', 'h.7.crossattention.c_proj.bias', 'h.5.crossattention.q_attn.weight', 'h.7.crossattention.masked_bias', 'h.4.crossattention.q_attn.weight', 'h.10.crossattention.bias', 'h.8.ln_cross_attn.weight', 'h.11.crossattention.c_attn.weight', 'h.2.crossattention.c_attn.weight', 'h.1.ln_cross_attn.weight', 'h.11.crossattention.bias', 'h.2.ln_cross_attn.weight', 'h.3.ln_cross_attn.weight', 'h.3.crossattention.q_attn.weight', 'h.6.crossattention.bias', 'h.9.ln_cross_attn.weight', 'h.2.crossattention.bias', 'h.8.crossattention.c_proj.weight', 'h.9.crossattention.masked_bias', 'h.9.crossattention.bias', 'h.2.crossattention.masked_bias', 'h.5.crossattention.c_proj.weight', 'h.11.ln_cross_attn.weight', 'h.6.crossattention.c_attn.weight', 'h.6.crossattention.q_attn.weight', 'h.0.crossattention.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Set the model in training mode

# %%
# We will do .train() to set the model in training model. If the model is not in training mode, the weights will not be updates. So, its not learning anything

model.train()

# Please note that model.eval() will be used while inference and evaluation stage
# Out:
# EncoderDecoderModel(
#   (encoder): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): GPT2LMHeadModel(
#     (transformer): GPT2Model(
#       (wte): Embedding(50257, 768)
#       (wpe): Embedding(1024, 768)
#       (drop): Dropout(p=0.1, inplace=False)
#       (h): ModuleList(
#         (0-11): 12 x GPT2Block(
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#             (resid_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (crossattention): GPT2Attention(
#             (c_attn): Conv1D()
#             (q_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#             (resid_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (ln_cross_attn): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (lm_head): Linear(in_features=768, out_features=50257, bias=False)
#   )
# )

# %%
# Total parameters for the model 

model.num_parameters()
# Out:
# 277452288

# %% [markdown]
# ### Load codebert's tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/codebert-base")

# %% [markdown]
# 1. Setting cls_token : To indicate start of sentence
# 2. Setting sep_token: To indicate end of sentence

# %% [markdown]
# #### The imports are for the following reasons:
#
# 1. The datasets is used to transform pandas dataframe to pyarrow (convinient to use with transformers)
# 2. The rouge_score and evalute libraries are for evalutaion metrics

# %%
# Importing the libraries

import datasets
import evaluate

# %%
# Loading the metric from huggingface datasets library to evaluate the model performance

rouge = datasets.load_metric("rouge")
bleu = evaluate.load("bleu")
meteor = evaluate.load("meteor")
# Out:
# /var/folders/wh/f71jmn_94ll19c_qkpz80d1c0000gn/T/ipykernel_66313/1472549025.py:3: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = datasets.load_metric("rouge")
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/6.81k [00:00<?, ?B/s]
# [nltk_data] Downloading package wordnet to /Users/Tushar/nltk_data...
# [nltk_data] Downloading package punkt to /Users/Tushar/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /Users/Tushar/nltk_data...

# %% [markdown]
# We define a function to evaluate rouge score and bleu-variants. This is optinal but gives us a better evaluation criteria for the model

# %%
def compute_metrics(pred):
    labels_ids = pred.label_ids
    pred_ids = pred.predictions

    # all unnecessary tokens are removed
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    labels_ids[labels_ids == -100] = tokenizer.pad_token_id
    label_str = tokenizer.batch_decode(labels_ids, skip_special_tokens=True)

    rouge_output = rouge.compute(predictions=pred_str, references=label_str, rouge_types=["rouge2"])["rouge2"].mid
    bleu1 = bleu.compute(predictions=pred_str, references=label_str,max_order=1)
    bleu2 = bleu.compute(predictions=pred_str, references=label_str, max_order=2)
    bleu3 = bleu.compute(predictions=pred_str, references=label_str, max_order=3)
    bleu4 = bleu.compute(predictions=pred_str, references=label_str, max_order=4)


    return {
        "rouge2_precision": round(rouge_output.precision, 4),
        "rouge2_recall": round(rouge_output.recall, 4),
        "rouge2_fmeasure": round(rouge_output.fmeasure, 4),
        "bleu1_score":round(bleu1["bleu"],4),
        "bleu2_score":round(bleu2["bleu"],4),
        "bleu3_score":round(bleu3["bleu"],4),
        "bleu4_score":round(bleu4["bleu"],4)
        }

# %% [markdown]
# We define a function to process the input data : code-diff files.
#
# The following are the steps involved:
#
# 1. It takes an input batch (16 (correlate with RAM)) from dataset.
# 2. The code-diff files and messages are tokenized using the codebert tokenizer.
# 3. Labels is just a copy of commit messages tokenized id's.
# 4. pad_token ids are set to -100 so that they are not considered during training and evaluation (high-level intuition).
#
# Things to note : A maximum size of 123 is considered for code-diff files and a maximum of 30 for commit messages (The values are based on the maximum tokens present in the set)
#
# **Hyper-parameters :**
#
# 1. batch_size
# 2. encoder_max_length
# 3. decoder_max_length

# %%
batch_size=16 
encoder_max_length=123
decoder_max_length=50

def process_data_to_model_inputs(batch):
  # tokenize the inputs and labels
  inputs = tokenizer(batch["commits"], padding="max_length", truncation=True, max_length=encoder_max_length)
  outputs = tokenizer(batch["message"], padding="max_length", truncation=True, max_length=decoder_max_length)

  batch["input_ids"] = inputs.input_ids
  batch["attention_mask"] = inputs.attention_mask

  #This was required in the earlier version, but internal implementation captures this so we don't have to provide
  # batch["decoder_input_ids"] = outputs.input_ids
  # batch["decoder_attention_mask"] = outputs.attention_mask
  
  batch["labels"] = outputs.input_ids.copy()

  # because BERT automatically shifts the labels, the labels correspond exactly to `decoder_input_ids`. 
  # We have to make sure that the PAD token is ignored
  batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] for labels in batch["labels"]]

  return batch

# %% [markdown]
# ### Set the model configuration
#
# This entirely depends on the type of encoder and decoder

# %%
# set special tokens
# We are setting the entire models special tokens
model.config.decoder_start_token_id = tokenizer.bos_token_id
model.config.eos_token_id = tokenizer.eos_token_id
model.config.pad_token_id = tokenizer.pad_token_id

# sensible parameters for beam search
model.config.vocab_size = model.config.decoder.vocab_size # Setting the models' vocabulary to GPT-2's vocabulary size (~50K)
model.config.max_length = 64 # Maximum length of message generated
model.config.min_length = 5 # Minimum length of message generated
model.config.no_repeat_ngram_size = 3 # A word will not be repeated more than three times while geenrating a new commit message
model.config.early_stopping = True
model.config.length_penalty = 2.0
model.config.num_beams = 4 # Top-4 words for beam search rather than considering all words for greedy search

# %% [markdown]
# ### Dataset restructuring

# %% [markdown]
# We are doing this to convert out pandas dataframe to pyarrow dataset. Pyarrow has good functionality and alignment with hugginface datasets library and we could use map function to manipulate the whole dataset according a fucntion provided.
#
# Overall, we could just write a manual function for preprocessing and use map function to extract all the input_ids and attention_masks.

# %%
import pyarrow as pa
from datasets import Dataset

# %%
train_set = Dataset(pa.Table.from_pandas(train_data))

# %%
val_set = Dataset(pa.Table.from_pandas(val_data))

# %% [markdown]
# ### Data mapping and batch conversions according to the function
# This section take the data and maps the data according to the funtion (1st argument) behaviour. We also define the batch size which is a hyperparameter

# %%
train_dataset = train_set.map(
    process_data_to_model_inputs, 
    batched=True, 
    batch_size=batch_size, 
    remove_columns=["commits", "message"]
)


train_dataset.set_format(
    type="torch", columns=["input_ids", "attention_mask", "labels"],
)
# Out:
# Map:   0%|          | 0/27707 [00:00<?, ? examples/s]

# %%
val_dataset = val_set.map(
    process_data_to_model_inputs, 
    batched=True, 
    batch_size=batch_size, 
    remove_columns=["commits", "message"]
)


val_dataset.set_format(
    type="torch", columns=["input_ids", "attention_mask", "labels"],
)
# Out:
# Map:   0%|          | 0/2573 [00:00<?, ? examples/s]

# %% [markdown]
# Now, we have all the input_ids, attention_masks and labels for train and validation set

# %% [markdown]
# ### We are using a trainer from Hugginface
# We are using **Seq2SeqTrainingArguments** and **Seq2SeqTrainer** from Hugginface.
#
# **trainin_args** variable holds the hyperparameters. Feel free to explore all the hyperparameters on huggingface website
#
# trainer variable is to initialize the trianer and pass model, datasets and metric funtion that we defined.

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer

training_args = Seq2SeqTrainingArguments(
    predict_with_generate=True, 
    overwrite_output_dir=True, # Overwrites previously saved model
    learning_rate=5e-5,
    evaluation_strategy="steps",
    logging_steps=1_000, 
    # Batch size for train and validaiton. 
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    output_dir = "./", # Saves the model to current directory
    save_steps=100, # Save the model to output directory after every 500 steps
    eval_steps=300,
    warmup_steps=200,
    save_total_limit=1, # Saves one file.
    num_train_epochs=0.2, # 0.2 epochs. Increase 
)


trainer = Seq2SeqTrainer(
    model=model, # Modelname
    tokenizer=tokenizer, # Tokenzier 
    args=training_args, # Hyperparameter arguments
    compute_metrics=compute_metrics, # Not mandatory (Manually defined rouge metric function)
    # Datasets
    train_dataset=train_data, 
    eval_dataset=val_data
    )

# %%
# call .train on trainer to start training. 

trainer.train()
# Out:
# /Users/Tushar/Dal/Teaching/4130_6314/ml4se/commit_message_generation/venv/lib/python3.9/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /Users/Tushar/Dal/Teaching/4130_6314/ml4se/commit_message_generation/venv/lib/python3.9/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='2' max='347' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  2/347 : < :, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# /Users/Tushar/Dal/Teaching/4130_6314/ml4se/commit_message_generation/venv/lib/python3.9/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /Users/Tushar/Dal/Teaching/4130_6314/ml4se/commit_message_generation/venv/lib/python3.9/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /Users/Tushar/Dal/Teaching/4130_6314/ml4se/commit_message_generation/venv/lib/python3.9/site-packages/transformers/generation/utils.py:1201: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# /Users/Tushar/Dal/Teaching/4130_6314/ml4se/commit_message_generation/venv/lib/python3.9/site-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:634: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# TrainOutput(global_step=347, training_loss=6.105830387698127, metrics={'train_runtime': 12637.5712, 'train_samples_per_second': 0.438, 'train_steps_per_second': 0.027, 'total_flos': 815662345789440.0, 'train_loss': 6.105830387698127, 'epoch': 0.2})

# %% [markdown]
# ## Testing the trained model
#
# It follows similar steps as previous except that we are not training the model, but just using the trained model to produce results and compare

# %% [markdown]
# ### Preprocessing

# %%
diff = pd.read_csv("data/test.3000.diff", sep="/n")
# Out:
# /var/folders/wh/f71jmn_94ll19c_qkpz80d1c0000gn/T/ipykernel_66313/921311270.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   diff = pd.read_csv("data/test.3000.diff", sep="/n")

# %%
mess = pd.read_csv("data/test.3000.msg", sep="/n")
# Out:
# /var/folders/wh/f71jmn_94ll19c_qkpz80d1c0000gn/T/ipykernel_66313/2669639711.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   mess = pd.read_csv("data/test.3000.msg", sep="/n")

# %%
diff["commits"] = diff[diff.columns[0]]
mess["message"] = mess[mess.columns[0]]

# %%
diff.drop(diff.columns[0], inplace=True, axis=1)
mess.drop(mess.columns[0], inplace=True, axis=1)

# %%
diff["commits"][6]
# Out:
# 'mmm a / library / src / androidTest / assets / ts / sample . ts . 0 . dump <nl> ppp b / library / src / androidTest / assets / ts / sample . ts . 0 . dump <nl> track 257 : <nl> encoderPadding = - 1 <nl> subsampleOffsetUs = 9223372036854775807 <nl> selectionFlags = 0 <nl> - language = null <nl> + language = und <nl> drmInitData = - <nl> initializationData : <nl> sample count = 4 <nl>'

# %% [markdown]
# ### converting to pyarrow dataset

# %%
val = Dataset(pa.Table.from_pandas(diff))

# %%
import datasets
from transformers import AutoTokenizer, EncoderDecoderModel

# %%
tokenizer = AutoTokenizer.from_pretrained("checkpoint-300") # Please find the checkpoint save in the current directotry
model = EncoderDecoderModel.from_pretrained("checkpoint-300")

# Loading the model to gpu
model.to()
# Out:
# EncoderDecoderModel(
#   (encoder): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): GPT2LMHeadModel(
#     (transformer): GPT2Model(
#       (wte): Embedding(50257, 768)
#       (wpe): Embedding(1024, 768)
#       (drop): Dropout(p=0.1, inplace=False)
#       (h): ModuleList(
#         (0-11): 12 x GPT2Block(
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#             (resid_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (crossattention): GPT2Attention(
#             (c_attn): Conv1D()
#             (q_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#             (resid_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (ln_cross_attn): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (lm_head): Linear(in_features=768, out_features=50257, bias=False)
#   )
# )

# %%
def generate_summary(batch):
    # Tokenizer will automatically set [BOS] <text> [EOS]
    inputs = tokenizer(batch["commits"], padding="max_length", truncation=True, max_length=123, return_tensors="pt")
    input_ids = inputs["input_ids"]
    attention_mask = inputs["attention_mask"]

    outputs = model.generate(input_ids, attention_mask=attention_mask)

    # all special tokens including will be removed
    output_str = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    batch["pred"] = output_str

    return batch

# %% [markdown]
# Increase the batch size if you want faster computation of ids and attetnion_mask.

# %%
results = val.map(generate_summary, batched=True, batch_size=16)
# Out:
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# /Users/Tushar/Dal/Teaching/4130_6314/ml4se/commit_message_generation/venv/lib/python3.9/site-packages/transformers/generation/utils.py:1288: UserWarning: Using `max_length`'s default (64) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
pred_str = results["pred"]
label_str = mess["message"]

rouge_output = rouge.compute(predictions=pred_str, references=label_str)
bleu1 = bleu.compute(predictions=pred_str, references=label_str,max_order=1)
bleu2 = bleu.compute(predictions=pred_str, references=label_str, max_order=2)
bleu3 = bleu.compute(predictions=pred_str, references=label_str, max_order=3)
bleu4 = bleu.compute(predictions=pred_str, references=label_str, max_order=4)
meteor = meteor.compute(predictions=pred_str, references=label_str)

print("Rouge: ",rouge_output)
print("Bleu-1: ", bleu1["bleu"])
print("Bleu-2: ",bleu2["bleu"])
print("Bleu-3: ",bleu3["bleu"])
print("Bleu-4: ", bleu4["bleu"])
print("Meteor: ",meteor["meteor"])
#print(bert_score)
# Out:
# Rouge:  {'rouge1': AggregateScore(low=Score(precision=0.17432769510582036, recall=0.15166503997259434, fmeasure=0.1577639698120864), mid=Score(precision=0.1843473544973546, recall=0.16036496906076061, fmeasure=0.1667822329262441), high=Score(precision=0.19457709656084662, recall=0.17029218494114784, fmeasure=0.17658605636205219)), 'rouge2': AggregateScore(low=Score(precision=0.10098134259259267, recall=0.09132324153185986, fmeasure=0.09500399801202845), mid=Score(precision=0.10981620370370407, recall=0.09955739759752918, fmeasure=0.10336962011536817), high=Score(precision=0.11866013888888938, recall=0.10811039283815609, fmeasure=0.11171809107979032)), 'rougeL': AggregateScore(low=Score(precision=0.17148819113756672, recall=0.14928984402513368, fmeasure=0.15541111161210544), mid=Score(precision=0.1813866402116406, recall=0.15833468772624287, fmeasure=0.16455263505622872), high=Score(precision=0.1911567989417998, recall=0.1675957024868199, fmeasure=0.17371346136456617)), 'rougeLsum': AggregateScore(low=Score(precision=0.17158924933862482, recall=0.14946186784876536, fmeasure=0.15555426352150767), mid=Score(precision=0.18089735449735478, recall=0.1579134134252086, fmeasure=0.16410204437072579), high=Score(precision=0.19067329365079405, recall=0.16690082575889634, fmeasure=0.1731267322439537))}
# Bleu-1:  0.2137221254822973
# Bleu-2:  0.13964143122876657
# Bleu-3:  0.09371854076328232
# Bleu-4:  0.06278388465766176
# Meteor:  0.14785082008747732

# %%
rouge_output["rougeL"].mid
# Out:
# Score(precision=0.1813866402116406, recall=0.15833468772624287, fmeasure=0.16455263505622872)
